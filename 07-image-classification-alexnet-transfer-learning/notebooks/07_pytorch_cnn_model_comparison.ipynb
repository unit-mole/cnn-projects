# %% [markdown]
# # Project 07 — PyTorch CNN Comparison
#
# Native-Windows RTX workflow matching the Transformer projects.

# %%
import sys, torch
print(sys.version)
print('PyTorch:', torch.__version__)
print('CUDA:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# PyTorch: 2.13.0+cu130
# CUDA: True
# GPU: NVIDIA GeForce RTX 5090

# %% [markdown]
# ## Validate project

# %%
# %run ../scripts/validate_project.py
# Out:
# Project validation passed (11 required assets).

# %% [markdown]
# ## Run the complete four-model experiment
# This cell trains Simple CNN, AlexNet-style CNN, frozen MobileNetV2, and fine-tuned MobileNetV2.

# %%
# %run ../scripts/run_full_experiment.py
# Out:
# Runtime: {'python_device': 'cuda', 'torch_version': '2.13.0+cu130', 'cuda_available': True, 'cuda_version': '13.0', 'gpu_name': 'NVIDIA GeForce RTX 5090', 'gpu_count': 1, 'mixed_precision': True}
# 100%|██████████| 170M/170M [29:12<00:00, 97.3kB/s]
# C:\Users\atripathi\OneDrive - Veralto\Desktop\AI Codes\GIT Projects\cnn-projects\07-image-classification-alexnet-transfer-learning\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# ===== Training simple_cnn =====
# Epoch 01/22 | train loss 0.8316 acc 0.6360 | val loss 0.8481 acc 0.6805
# Epoch 02/22 | train loss 0.6756 acc 0.7100 | val loss 0.6463 acc 0.7315
# Epoch 03/22 | train loss 0.6159 acc 0.7371 | val loss 0.9334 acc 0.6221
# ...

# %% [markdown]
# ## Review leaderboard

# %%
import pandas as pd, json
display(pd.read_csv('../outputs/model_leaderboard.csv'))
print(json.dumps(json.load(open('../outputs/selected_deployment_model.json')), indent=2))
# Out:
#                    model  accuracy  balanced_accuracy  macro_precision  \
# 0  mobilenetv2_finetuned    0.9103           0.915125         0.903964
# 1          alexnet_style    0.9024           0.900188         0.903096
# 2     mobilenetv2_frozen    0.8736           0.883438         0.863283
# 3             simple_cnn    0.8635           0.875500         0.858783
#
#    macro_recall  macro_f1  weighted_f1  top2_accuracy  roc_auc_ovr_macro  \
# 0      0.915125  0.908879     0.909966         0.9874           0.989422
# 1      0.900188  0.901379     0.901907         0.9839           0.983882
# 2      0.883438  0.871641     0.873338         0.9746           0.980244
# 3      0.875500  0.865900     0.863819         0.9796           0.975818
#
#    negative_log_likelihood  brier_score  expected_calibration_error  \
# 0                 0.232741     0.129282                    0.006609
# 1                 0.450738     0.165533                    0.068786
# ...

# %% [markdown]
# ## Export selected model to ONNX

# %%
# %run ../scripts/export_to_onnx.py
# Out:
# Exported: C:\Users\atripathi\OneDrive - Veralto\Desktop\AI Codes\GIT Projects\cnn-projects\07-image-classification-alexnet-transfer-learning\models\onnx_model\model.onnx
# Copied to: C:\Users\atripathi\OneDrive - Veralto\Desktop\AI Codes\GIT Projects\cnn-projects\07-image-classification-alexnet-transfer-learning\web\model\model.onnx

# %% [markdown]
# ## Validate browser deployment

# %%
# %run ../scripts/validate_project.py --require-onnx
# Out:
# Project validation passed (11 required assets).
